# %%
import stemgraphic
import pandas as pd
import numpy as np

# %%
Aptitude = pd.read_csv('App_data.csv')
data = np.array(Aptitude)
stemgraphic.stem_graphic(data, scale = 10)
# Out:
# (<Figure size 540x216 with 1 Axes>, <Axes:>)
