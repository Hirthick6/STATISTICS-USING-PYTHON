# %%
import pandas as pd

# %%
paddy=pd.read_excel('PADDY DATA SET.xlsx')

# %%
paddy.head()
# Out:
#   TYPES OF PADDY               X                  Y PERIOD  STARTING DURATION  \
# 0          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
# 1          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
# 2          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
# 3          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
# 4          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
#
#    ENDING DURATION  AVERAGE YIELD(Kg/ha)  1000 GRAIN WEIGHT(g)    GRAIN TYPE  \
# 0            120.0                6146.0                  23.1  Long Slender
# 1            120.0                6146.0                  23.1  Long Slender
# 2            120.0                6146.0                  23.1  Long Slender
# 3            120.0                6146.0                  23.1  Long Slender
# 4            120.0                6146.0                  23.1  Long Slender
#
# ...

# %%
paddy['Code']=pd.factorize(paddy.DISTRICT)[0]

# %%
paddy.DISTRICT.value_counts()
# Out:
# Theni              22
# Madurai            22
# Kanchipuram        20
# Tiruvannamalai     20
# Vellore            20
# Cuddalore          20
# Villupuram         20
# Nagapattinam       19
# Tiruvarur          19
# Kanyakumari        19
# Thanjavur          19
# Pudukottai         18
# Dindigal           17
# Erode              17
# Krishnagiri        17
# Dharmapuri         17
# Salem              16
# Namakkal           16
# Coimbatore         16
# Karur              16
# Thoothukudi        15
# Tirunelveli        15
# Perambalur         14
# Thiruvallur        10
# Tiruchirappali      9
# Tiruvallur          9
# Ramanathapuram      9
# Virudhunagar        7
# Dindigul            5
# Tiruchirappalli     5
# Sivaganga           4
# Tiruchirapalli      2
# Perembalur          2
# The Nilgiris        1
# Nilgiris            1
# thiruvallur         1
# TheNilgiris         1
# Name: DISTRICT, dtype: int64

# %%
paddy.Code.value_counts()
# Out:
# 15    22
# 13    22
# 0     20
# 2     20
# 3     20
# 4     20
# 6     20
# 10    19
# 11    19
# 18    19
# 9     19
# 12    18
# 30    17
# 24    17
# 22    17
# 21    17
# 19    16
# 20    16
# 23    16
# 7     16
# 17    15
# 16    15
# 8     14
# 28    10
# 29     9
# 1      9
# 25     9
# 26     7
# 14     5
# 5      5
# 27     4
# 35     2
# 36     2
# 31     1
# 32     1
# 33     1
# 34     1
# Name: Code, dtype: int64

# %%
paddy.head()
# Out:
#   TYPES OF PADDY               X                  Y PERIOD  STARTING DURATION  \
# 0          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
# 1          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
# 2          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
# 3          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
# 4          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
#
#    ENDING DURATION  AVERAGE YIELD(Kg/ha)  1000 GRAIN WEIGHT(g)    GRAIN TYPE  \
# 0            120.0                6146.0                  23.1  Long Slender
# 1            120.0                6146.0                  23.1  Long Slender
# 2            120.0                6146.0                  23.1  Long Slender
# 3            120.0                6146.0                  23.1  Long Slender
# 4            120.0                6146.0                  23.1  Long Slender
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
paddy['Code_le']=le.fit_transform(paddy.DISTRICT)

# %%
paddy.head()
# Out:
#   TYPES OF PADDY               X                  Y PERIOD  STARTING DURATION  \
# 0          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
# 1          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
# 2          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
# 3          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
# 4          IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3  Short              115.0
#
#    ENDING DURATION  AVERAGE YIELD(Kg/ha)  1000 GRAIN WEIGHT(g)    GRAIN TYPE  \
# 0            120.0                6146.0                  23.1  Long Slender
# 1            120.0                6146.0                  23.1  Long Slender
# 2            120.0                6146.0                  23.1  Long Slender
# 3            120.0                6146.0                  23.1  Long Slender
# 4            120.0                6146.0                  23.1  Long Slender
#
# ...
