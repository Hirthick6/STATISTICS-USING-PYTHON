# %%
#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Loading the dataset
data = load_boston()
df = pd.read_excel("PADDY DATA SET.xlsx")
df
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)
#     TYPES OF PADDY               X                  Y  PERIOD  \
# 0            IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3   Short
# 1            IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3   Short
# 2            IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3   Short
# 3            IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3   Short
# 4            IR 64  IR 5657_33_2_1  IR 2061_465_1_5_3   Short
# ..             ...             ...                ...     ...
# 475        ADTRH 1      IR 58025 A            IR 66 R  Hybrid
# 476        ADTRH 1      IR 58025 A            IR 66 R  Hybrid
# 477        ADTRH 1      IR 58025 A            IR 66 R  Hybrid
# 478        ADTRH 1      IR 58025 A            IR 66 R  Hybrid
# 479        ADTRH 1      IR 58025 A            IR 66 R  Hybrid
#
#      STARTING DURATION  ENDING DURATION  AVERAGE YIELD(Kg/ha)  \
# 0                115.0            120.0                6146.0
# 1                115.0            120.0                6146.0
# 2                115.0            120.0                6146.0
# 3                115.0            120.0                6146.0
# 4                115.0            120.0                6146.0
# ..                 ...              ...                   ...
# 475              110.0            115.0                6400.0
# 476              110.0            115.0                6400.0
# 477              110.0            115.0                6400.0
# 478              110.0            115.0                6400.0
# 479              110.0            115.0                6400.0
#
#      1000 GRAIN WEIGHT(g)    GRAIN TYPE              HABIT  \
# 0                    23.1  Long Slender         Semi dwarf
# 1                    23.1  Long Slender         Semi dwarf
# 2                    23.1  Long Slender         Semi dwarf
# 3                    23.1  Long Slender         Semi dwarf
# 4                    23.1  Long Slender         Semi dwarf
# ..                    ...           ...                ...
# 475                  23.8  Long slender  Semi dwarf, erect
# 476                  23.8  Long slender  Semi dwarf, erect
# 477                  23.8  Long slender  Semi dwarf, erect
# 478                  23.8  Long slender  Semi dwarf, erect
# 479                  23.8  Long slender  Semi dwarf, erect
#
#                RICE COLOR                               SPECIAL FEATURES  \
# 0                   White  High-yielding and high-quality indica variety
# 1                   White  High-yielding and high-quality indica variety
# 2                   White  High-yielding and high-quality indica variety
# 3                   White  High-yielding and high-quality indica variety
# 4                   White  High-yielding and high-quality indica variety
# ..                    ...                                            ...
# 475  White milky, scented                           High yield potential
# 476  White milky, scented                           High yield potential
# 477  White milky, scented                           High yield potential
# 478  White milky, scented                           High yield potential
# 479  White milky, scented                           High yield potential
#
#     STARTING MONTH ENDING MONTH        DISTRICT  RAINFALL ACTUAL(in mm)  \
# 0            April          May     Kanchipuram                   397.0
# 1            April          May      Tiruvallur                     9.5
# 2            April          May  Tiruvannamalai                    44.3
# 3            April          May         Vellore                   318.1
# 4            April          May       Cuddalore                     5.6
# ..             ...          ...             ...                     ...
# 475            May         June     Kanyakumari                   402.8
# 476            May         June      Dharmapuri                   170.6
# 477            May         June     Krishnagiri                   222.2
# 478            May         June      Coimbatore                   652.3
# 479            May         June           Erode                   282.9
#
#      RAINFALL NORMAL(in mm)  TMAX (°F)  TMIN (°F)
# 0                     490.8        100         78
# 1                      67.2         99         79
# 2                      98.9        102         76
# 3                     466.1        103         78
# 4                      81.7         93         81
# ..                      ...        ...        ...
# 475                   496.4         89         79
# 476                   393.4         96         77
# 477                   399.0         95         77
# 478                   189.8         92         75
# 479                   229.8         99         80
#
# [480 rows x 19 columns]

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
df=df.apply(LabelEncoder().fit_transform)
df
# Out:
#      TYPES OF PADDY   X   Y  PERIOD  STARTING DURATION  ENDING DURATION  \
# 0                18  13  10       3                  4                5
# 1                18  13  10       3                  4                5
# 2                18  13  10       3                  4                5
# 3                18  13  10       3                  4                5
# 4                18  13  10       3                  4                5
# ..              ...  ..  ..     ...                ...              ...
# 475               6  15  13       0                  3                4
# 476               6  15  13       0                  3                4
# 477               6  15  13       0                  3                4
# 478               6  15  13       0                  3                4
# 479               6  15  13       0                  3                4
#
#      AVERAGE YIELD(Kg/ha)  1000 GRAIN WEIGHT(g)  GRAIN TYPE  HABIT  \
# 0                      14                    13           0      4
# 1                      14                    13           0      4
# 2                      14                    13           0      4
# 3                      14                    13           0      4
# 4                      14                    13           0      4
# ..                    ...                   ...         ...    ...
# 475                    16                    18           1      8
# 476                    16                    18           1      8
# 477                    16                    18           1      8
# 478                    16                    18           1      8
# 479                    16                    18           1      8
#
#      RICE COLOR  SPECIAL FEATURES  STARTING MONTH  ENDING MONTH  DISTRICT  \
# 0             0                 2               0             4         6
# 1             0                 2               0             4        30
# 2             0                 2               0             4        31
# 3             0                 2               0             4        33
# 4             0                 2               0             4         1
# ..          ...               ...             ...           ...       ...
# 475           1                 1               5             3         7
# 476           1                 1               5             3         2
# 477           1                 1               5             3         9
# 478           1                 1               5             3         0
# 479           1                 1               5             3         5
#
#      RAINFALL ACTUAL(in mm)  RAINFALL NORMAL(in mm)  TMAX (°F)  TMIN (°F)
# 0                        54                      60         16         13
# 1                        14                      16         15         14
# 2                        20                      21         17         11
# 3                        47                      55         18         13
# 4                         9                      19          9         16
# ..                      ...                     ...        ...        ...
# 475                      55                      61          5         14
# 476                      30                      48         12         12
# 477                      34                      49         11         12
# 478                      60                      28          8         10
# 479                      44                      31         15         15
#
# [480 rows x 19 columns]

# %%
data.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
X = df.drop("DISTRICT",axis=1)   #Feature Matrix
y = df["DISTRICT"]

# %%
df.head()
# Out:
#    TYPES OF PADDY   X   Y  PERIOD  STARTING DURATION  ENDING DURATION  \
# 0              18  13  10       3                  4                5
# 1              18  13  10       3                  4                5
# 2              18  13  10       3                  4                5
# 3              18  13  10       3                  4                5
# 4              18  13  10       3                  4                5
#
#    AVERAGE YIELD(Kg/ha)  1000 GRAIN WEIGHT(g)  GRAIN TYPE  HABIT  RICE COLOR  \
# 0                    14                    13           0      4           0
# 1                    14                    13           0      4           0
# 2                    14                    13           0      4           0
# 3                    14                    13           0      4           0
# 4                    14                    13           0      4           0
#
#    SPECIAL FEATURES  STARTING MONTH  ENDING MONTH  DISTRICT  \
# 0                 2               0             4         6
# 1                 2               0             4        30
# 2                 2               0             4        31
# 3                 2               0             4        33
# 4                 2               0             4         1
#
#    RAINFALL ACTUAL(in mm)  RAINFALL NORMAL(in mm)  TMAX (°F)  TMIN (°F)
# 0                      54                      60         16         13
# 1                      14                      16         15         14
# 2                      20                      21         17         11
# 3                      47                      55         18         13
# 4                       9                      19          9         16

# %%
X.head()
# Out:
#    TYPES OF PADDY   X   Y  PERIOD  STARTING DURATION  ENDING DURATION  \
# 0              18  13  10       3                  4                5
# 1              18  13  10       3                  4                5
# 2              18  13  10       3                  4                5
# 3              18  13  10       3                  4                5
# 4              18  13  10       3                  4                5
#
#    AVERAGE YIELD(Kg/ha)  1000 GRAIN WEIGHT(g)  GRAIN TYPE  HABIT  RICE COLOR  \
# 0                    14                    13           0      4           0
# 1                    14                    13           0      4           0
# 2                    14                    13           0      4           0
# 3                    14                    13           0      4           0
# 4                    14                    13           0      4           0
#
#    SPECIAL FEATURES  STARTING MONTH  ENDING MONTH  RAINFALL ACTUAL(in mm)  \
# 0                 2               0             4                      54
# 1                 2               0             4                      14
# 2                 2               0             4                      20
# 3                 2               0             4                      47
# 4                 2               0             4                       9
#
#    RAINFALL NORMAL(in mm)  TMAX (°F)  TMIN (°F)
# 0                      60         16         13
# 1                      16         15         14
# 2                      21         17         11
# 3                      55         18         13
# 4                      19          9         16

# %%
# separate dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((336, 18), (144, 18))

# %%
X_train.corr()
# Out:
#                         TYPES OF PADDY         X         Y    PERIOD  \
# TYPES OF PADDY                1.000000  0.304253 -0.005750 -0.192883
# X                             0.304253  1.000000  0.011874 -0.165677
# Y                            -0.005750  0.011874  1.000000  0.218012
# PERIOD                       -0.192883 -0.165677  0.218012  1.000000
# STARTING DURATION             0.417684  0.030995 -0.207158 -0.486301
# ENDING DURATION               0.369782  0.032988 -0.197740 -0.468429
# AVERAGE YIELD(Kg/ha)         -0.359841 -0.524820  0.037448 -0.105861
# 1000 GRAIN WEIGHT(g)          0.111243 -0.305411 -0.409171 -0.226271
# GRAIN TYPE                   -0.046032  0.000599  0.093217  0.052828
# HABIT                        -0.303035 -0.204723  0.209433 -0.230874
# RICE COLOR                   -0.149517 -0.087296  0.099821 -0.336073
# SPECIAL FEATURES             -0.075838 -0.365247  0.192883  0.230618
# STARTING MONTH               -0.064933  0.020925  0.080544  0.064284
# ENDING MONTH                 -0.163752 -0.060666  0.038111  0.208482
# RAINFALL ACTUAL(in mm)        0.124697  0.024467 -0.029500 -0.140248
# RAINFALL NORMAL(in mm)        0.149850 -0.001743 -0.058143 -0.168713
# TMAX (°F)                    -0.086350 -0.089448  0.004243  0.153549
# TMIN (°F)                    -0.040593 -0.061381 -0.005737 -0.044000
#
#                         STARTING DURATION  ENDING DURATION  \
# TYPES OF PADDY                   0.417684         0.369782
# X                                0.030995         0.032988
# Y                               -0.207158        -0.197740
# PERIOD                          -0.486301        -0.468429
# STARTING DURATION                1.000000         0.990378
# ENDING DURATION                  0.990378         1.000000
# AVERAGE YIELD(Kg/ha)            -0.224347        -0.202209
# 1000 GRAIN WEIGHT(g)            -0.030755        -0.068109
# GRAIN TYPE                       0.087002         0.147282
# HABIT                            0.147751         0.223359
# RICE COLOR                       0.068248         0.054467
# SPECIAL FEATURES                 0.192138         0.226553
# STARTING MONTH                  -0.212731        -0.224131
# ENDING MONTH                    -0.319386        -0.332017
# RAINFALL ACTUAL(in mm)           0.222567         0.216513
# RAINFALL NORMAL(in mm)           0.302568         0.310749
# TMAX (°F)                       -0.184652        -0.180334
# TMIN (°F)                        0.002843         0.009604
#
#                         AVERAGE YIELD(Kg/ha)  1000 GRAIN WEIGHT(g)  \
# TYPES OF PADDY                     -0.359841              0.111243
# X                                  -0.524820             -0.305411
# Y                                   0.037448             -0.409171
# PERIOD                             -0.105861             -0.226271
# STARTING DURATION                  -0.224347             -0.030755
# ENDING DURATION                    -0.202209             -0.068109
# AVERAGE YIELD(Kg/ha)                1.000000              0.340695
# 1000 GRAIN WEIGHT(g)                0.340695              1.000000
# GRAIN TYPE                         -0.200487             -0.109819
# HABIT                               0.326003             -0.020241
# RICE COLOR                          0.360559              0.321632
# SPECIAL FEATURES                    0.057734             -0.104370
# STARTING MONTH                      0.001618              0.016342
# ENDING MONTH                        0.094270              0.086957
# RAINFALL ACTUAL(in mm)             -0.115484             -0.053382
# RAINFALL NORMAL(in mm)             -0.066954             -0.028053
# TMAX (°F)                           0.112124              0.144470
# TMIN (°F)                           0.048484              0.062835
#
#                         GRAIN TYPE     HABIT  RICE COLOR  SPECIAL FEATURES  \
# TYPES OF PADDY           -0.046032 -0.303035   -0.149517         -0.075838
# X                         0.000599 -0.204723   -0.087296         -0.365247
# Y                         0.093217  0.209433    0.099821          0.192883
# PERIOD                    0.052828 -0.230874   -0.336073          0.230618
# STARTING DURATION         0.087002  0.147751    0.068248          0.192138
# ENDING DURATION           0.147282  0.223359    0.054467          0.226553
# AVERAGE YIELD(Kg/ha)     -0.200487  0.326003    0.360559          0.057734
# 1000 GRAIN WEIGHT(g)     -0.109819 -0.020241    0.321632         -0.104370
# GRAIN TYPE                1.000000  0.393689    0.048230          0.038207
# HABIT                     0.393689  1.000000    0.341032          0.056204
# RICE COLOR                0.048230  0.341032    1.000000         -0.110298
# SPECIAL FEATURES          0.038207  0.056204   -0.110298          1.000000
# STARTING MONTH           -0.005914 -0.058139   -0.024645         -0.123895
# ENDING MONTH              0.026868 -0.030627    0.144884         -0.202196
# RAINFALL ACTUAL(in mm)    0.057615  0.075324   -0.064011         -0.007498
# RAINFALL NORMAL(in mm)    0.128627  0.135976   -0.061347          0.014154
# TMAX (°F)                 0.173958  0.074138    0.162153         -0.121517
# TMIN (°F)                 0.171678  0.105683    0.062097         -0.072994
#
#                         STARTING MONTH  ENDING MONTH  RAINFALL ACTUAL(in mm)  \
# TYPES OF PADDY               -0.064933     -0.163752                0.124697
# X                             0.020925     -0.060666                0.024467
# Y                             0.080544      0.038111               -0.029500
# PERIOD                        0.064284      0.208482               -0.140248
# STARTING DURATION            -0.212731     -0.319386                0.222567
# ENDING DURATION              -0.224131     -0.332017                0.216513
# AVERAGE YIELD(Kg/ha)          0.001618      0.094270               -0.115484
# 1000 GRAIN WEIGHT(g)          0.016342      0.086957               -0.053382
# GRAIN TYPE                   -0.005914      0.026868                0.057615
# HABIT                        -0.058139     -0.030627                0.075324
# RICE COLOR                   -0.024645      0.144884               -0.064011
# SPECIAL FEATURES             -0.123895     -0.202196               -0.007498
# STARTING MONTH                1.000000      0.483157                0.334765
# ENDING MONTH                  0.483157      1.000000                0.070412
# RAINFALL ACTUAL(in mm)        0.334765      0.070412                1.000000
# RAINFALL NORMAL(in mm)        0.240487      0.103757                0.687443
# TMAX (°F)                    -0.187423      0.165705               -0.023836
# TMIN (°F)                    -0.041249     -0.070285               -0.088246
#
#                         RAINFALL NORMAL(in mm)  TMAX (°F)  TMIN (°F)
# TYPES OF PADDY                        0.149850  -0.086350  -0.040593
# X                                    -0.001743  -0.089448  -0.061381
# Y                                    -0.058143   0.004243  -0.005737
# PERIOD                               -0.168713   0.153549  -0.044000
# STARTING DURATION                     0.302568  -0.184652   0.002843
# ENDING DURATION                       0.310749  -0.180334   0.009604
# AVERAGE YIELD(Kg/ha)                 -0.066954   0.112124   0.048484
# 1000 GRAIN WEIGHT(g)                 -0.028053   0.144470   0.062835
# GRAIN TYPE                            0.128627   0.173958   0.171678
# HABIT                                 0.135976   0.074138   0.105683
# RICE COLOR                           -0.061347   0.162153   0.062097
# SPECIAL FEATURES                      0.014154  -0.121517  -0.072994
# STARTING MONTH                        0.240487  -0.187423  -0.041249
# ENDING MONTH                          0.103757   0.165705  -0.070285
# RAINFALL ACTUAL(in mm)                0.687443  -0.023836  -0.088246
# RAINFALL NORMAL(in mm)                1.000000   0.132187   0.162270
# TMAX (°F)                             0.132187   1.000000   0.439854
# TMIN (°F)                             0.162270   0.439854   1.000000

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.7)
len(set(corr_features))
# Out:
# 1

# %%
corr_features
# Out:
# {'ENDING DURATION'}

# %%
X_train.drop(corr_features,axis=1)
X_test.drop(corr_features,axis=1)
# Out:
#      TYPES OF PADDY   X   Y  PERIOD  STARTING DURATION  AVERAGE YIELD(Kg/ha)  \
# 15               18  13  10       3                  4                    14
# 124               7   1   5       3                  3                     8
# 141               7   1   5       3                  3                     8
# 263              12   6   9       2                  8                     4
# 170              10  14  15       3                  2                    12
# ..              ...  ..  ..     ...                ...                   ...
# 68                0  26   9       3                  2                     0
# 20               18  13  10       3                  4                    14
# 295               2   7  12       2                  7                    15
# 14               18  13  10       3                  4                    14
# 313               3  16   9       2                  5                     3
#
#      1000 GRAIN WEIGHT(g)  GRAIN TYPE  HABIT  RICE COLOR  SPECIAL FEATURES  \
# 15                     13           0      4           0                 2
# 124                    20           4      5           0                 4
# 141                    20           4      5           0                 4
# 263                     6           3      1           0                21
# 170                    11           0      1           0                17
# ..                    ...         ...    ...         ...               ...
# 68                      7           2      1           0                 8
# 20                     13           0      4           0                 2
# 295                     8           0      8           0                18
# 14                     13           0      4           0                 2
# 313                     3           3      4           0                 9
#
#      STARTING MONTH  ENDING MONTH  RAINFALL ACTUAL(in mm)  \
# 15                5             3                      57
# 124               0             4                      17
# 141               5             3                      34
# 263               1             0                      46
# 170               5             3                      37
# ..              ...           ...                     ...
# 68                5             3                      49
# 20                5             3                      37
# 295               1             0                      41
# 14                5             3                      40
# 313               6             5                      27
#
#      RAINFALL NORMAL(in mm)  TMAX (°F)  TMIN (°F)
# 15                       26         11         11
# 124                      18         13         14
# 141                      49         11         12
# 263                      57         11         10
# 170                      44         15         15
# ..                      ...        ...        ...
# 68                       53         14         14
# 20                       44         15         15
# 295                      43         10         21
# 14                       36         13         13
# 313                      40         10         14
#
# [144 rows x 17 columns]
