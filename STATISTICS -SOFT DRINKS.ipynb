# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df= pd.read_csv('Soft_drink.csv')
df
# Out:
#     Soft_Drinks  Frequency
# 0  Coke_Classic         19
# 1     Diet_Coke          8
# 2     Dr_Pepper          5
# 3         Pepsi         13
# 4        Sprite          5

# %%
df= pd.read_csv('sdrink.csv')
df
# Out:
#     Soft Drinks  Frequency  Relative Frequency  Percentage Frequency
# 0  coke classic         19                0.38                    38
# 1     diet coke          8                0.16                    16
# 2     dr.pepper          5                0.10                    10
# 3         pepsi         13                0.26                    26
# 4        spirit          5                0.10                    10

# %%
df.Frequency
# Out:
# 0    19
# 1     8
# 2     5
# 3    13
# 4     5
# Name: Frequency, dtype: int64

# %%
frequency=np.array(soft_drink.Frequency)
frequency
# Out:
# array([19,  8,  5, 13,  5], dtype=int64)

# %%
total = frequency.sum()

# %%
total
# Out:
# 50

# %%
relative_frequency = np.array(frequency/total)
relative_frequency
# Out:
# array([0.38, 0.16, 0.1 , 0.26, 0.1 ])

# %%
percent_frequency = np.array(relative_frequency*100)
percent_frequency
# Out:
# array([38., 16., 10., 26., 10.])

# %% [markdown]
# # Frequency

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
colour = ["blue","green","red","yellow","orange"]
plt.bar(df.Soft_Drinks,frequency,width = 0.5,color = colour)
plt.xlabel("Drink")
plt.ylabel("Frequency")
plt.title("Bar Graph for Frequency")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Relative Frequency

# %%
plt.bar(df.Soft_Drinks,relative_frequency,width = 0.5,color = colour)
plt.xlabel("Drink")
plt.ylabel("Relative_Frequency")
plt.title("Bar Graph for Relative_Frequency")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Percentage Frequency

# %%
plt.bar(soft_drink.Soft_Drinks,percent_frequency,width = 0.5,color = colour)
plt.xlabel("Drink")
plt.ylabel("Percent_Frequency")
plt.title("Bar Graph for Percent_Frequency")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Line Plot Graph

# %%
from matplotlib import rcParams
rcParams['figure.figsize']=10,6
plt.plot(df.Frequency)
plt.grid(True,color='k',linestyle=':')
plt.title("line Plot Graph")
plt.xlabel("Drink")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
from matplotlib import pyplot as plt
x=[0,1,2,3,4]
y=df.Frequency
plt.plot(x,y)
plt.title("line Plot Graph")
plt.xlabel("Drink")
plt.ylabel("Frequency")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Pie-Chart

# %%
plt.pie(percent_frequency,labels=soft_drink.Soft_Drinks,shadow=True,autopct='%1.1f%%',radius=1.5)
plt.axis("equal")
plt.title("Bar Graph for Percent_Frequency")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Donut Chart

# %%
plt.pie(percent_frequency,labels=soft_drink.Soft_Drinks,shadow=True,autopct='%1.1f%%',radius=1.5)
plt.axis("equal")
plt.title("Bar Graph for Percent_Frequency")
circle=plt.Circle(xy=(0,0),radius=.75,facecolor='white')
plt.gca().add_artist(circle)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
